# 6               Agnostic/Secular                    Studying
# 7                          Other                    Studying
# 8    Spiritual but not Religious                    Studying
# 9             Religious/Theistic  Extracurricular Activities
# 10            Atheist/Naturalist                    Studying
# 11            Religious/Theistic                    Studying
# 12            Atheist/Naturalist                    Studying
# 13            Atheist/Naturalist                        Work
# 14              Agnostic/Secular                    Studying
# 15            Religious/Theistic                    Studying
# 16            Religious/Theistic                    Studying
# 17   Spiritual but not Religious                    Studying
# 18   Spiritual but not Religious                        Work
# 19              Agnostic/Secular                        Work
# 20            Atheist/Naturalist                        Work
# 21              Agnostic/Secular                        Work
# 22   Spiritual but not Religious  Extracurricular Activities
# 23            Atheist/Naturalist               Social Events
# 24              Agnostic/Secular                        Work
# 25              Agnostic/Secular                        Work
# 26            Religious/Theistic                        Work
# 27              Agnostic/Secular                        Work
# 28            Atheist/Naturalist                        Work
# 29            Religious/Theistic                        Work
# 30   Spiritual but not Religious  Extracurricular Activities
# 31            Atheist/Naturalist                        Work
# 32            Religious/Theistic                        Work
# 33              Agnostic/Secular                        Work
# 34   Spiritual but not Religious                    Studying
# 35   Spiritual but not Religious                        Work
# 36   Spiritual but not Religious                        Work
# 37            Religious/Theistic                        Work
# 38            Religious/Theistic                        Work
# 39              Agnostic/Secular                        Work
# 40              Agnostic/Secular                        Work
# 41            Religious/Theistic                        Work
# 42                         Other  Extracurricular Activities
# 43   Spiritual but not Religious                    Studying
# 44            Atheist/Naturalist                        Work
# 45                         Other  Extracurricular Activities
# 46            Religious/Theistic               Student Clubs
# 47            Religious/Theistic               Student Clubs
# 48            Religious/Theistic  Extracurricular Activities
# 49              Agnostic/Secular               Student Clubs
# 50            Atheist/Naturalist                    Studying
# 51            Religious/Theistic                    Studying
# 52   Spiritual but not Religious                    Studying
# 53              Agnostic/Secular               Social Events
# 54            Atheist/Naturalist                    Studying
# 55            Atheist/Naturalist                    Studying
# 56            Atheist/Naturalist  Extracurricular Activities
# 57            Religious/Theistic  Extracurricular Activities
# 58              Agnostic/Secular  Extracurricular Activities
# 59            Religious/Theistic                    Studying
# 60            Religious/Theistic               Student Clubs
# 61            Atheist/Naturalist                    Studying
# 62            Religious/Theistic                    Studying
# 63   Spiritual but not Religious                    Studying
# 64            Religious/Theistic                    Studying
# 65            Religious/Theistic                    Studying
# 66   Spiritual but not Religious                    Studying
# 67            Religious/Theistic               Student Clubs
# 68            Religious/Theistic                    Studying
# 69            Religious/Theistic                    Studying
# 70            Atheist/Naturalist  Extracurricular Activities
# 71            Religious/Theistic                    Studying
# 72   Spiritual but not Religious               Social Events
# 73            Religious/Theistic               Student Clubs
# 74                         Other                        Work
# 75            Religious/Theistic  Extracurricular Activities
# 76              Agnostic/Secular               Student Clubs
# 77            Religious/Theistic                    Studying
# 78                         Other  Extracurricular Activities
# 79   Spiritual but not Religious                        Work
# 80            Atheist/Naturalist               Social Events
# 81            Religious/Theistic               Student Clubs
# 82   Spiritual but not Religious                    Studying
# 83   Spiritual but not Religious                        Work
# 84              Agnostic/Secular                        Work
# 85            Religious/Theistic                    Studying
# 86            Religious/Theistic                    Studying
# 87            Atheist/Naturalist  Extracurricular Activities
# 88            Religious/Theistic                        Work
# 89   Spiritual but not Religious               Social Events
# 90              Agnostic/Secular                        Work
# 91   Spiritual but not Religious                        Work
# 92            Atheist/Naturalist                    Studying
# 93              Agnostic/Secular                        Work
# 94            Atheist/Naturalist                        Work
# 95            Religious/Theistic  Extracurricular Activities
# 96   Spiritual but not Religious                        Work
# 97            Religious/Theistic                        Work
# 98   Spiritual but not Religious                        Work
# 99            Atheist/Naturalist                        Work
# 100           Atheist/Naturalist                        Work
#
#                                      regular_practices household_size  \
# 0                                    Artistic Creation            3-5
# 1                                                  NaN            3-5
# 2       Artistic Creation, Regular Immersion in Nature            <=2
# 3    Meditation/Mindfulness, Breath work, Yoga/Mart...            3-5
# 4    Yoga/Martial Arts, Artistic Creation, Regular ...            3-5
# 5    Meditation/Mindfulness, Breath work, Yoga/Mart...            3-5
# 6                                                  NaN            3-5
# 7                                                  NaN            3-5
# 8    Meditation/Mindfulness, Breath work, Artistic ...            <=2
# 9                                                  NaN            3-5
# 10                                   Yoga/Martial Arts            <=2
# 11   Meditation/Mindfulness, Regular Immersion in N...             6+
# 12                                                 NaN            <=2
# 13   Meditation/Mindfulness, Regular Immersion in N...            3-5
# 14           Meditation/Mindfulness, Artistic Creation            3-5
# 15   Meditation/Mindfulness, Regular Immersion in N...             6+
# 16                                                 NaN            3-5
# 17                 Meditation/Mindfulness, Breath work            3-5
# 18   Meditation/Mindfulness, Regular Immersion in N...            3-5
# 19                                                 NaN            3-5
# 20                                                 NaN            <=2
# 21                      Breath work, Artistic Creation            3-5
# 22                                                 NaN            <=2
# 23                                   Artistic Creation            3-5
# 24                                   Artistic Creation            <=2
# 25                                   Yoga/Martial Arts            3-5
# 26                                                 NaN            3-5
# 27                 Meditation/Mindfulness, Breath work            <=2
# 28                                                 NaN            3-5
# 29   Breath work, Artistic Creation, Regular Immers...             6+
# 30   Meditation/Mindfulness, Yoga/Martial Arts, Art...            3-5
# 31      Artistic Creation, Regular Immersion in Nature            <=2
# 32   Meditation/Mindfulness, Breath work, Yoga/Mart...            <=2
# 33                              Meditation/Mindfulness            <=2
# 34                                   Yoga/Martial Arts            NaN
# 35   Meditation/Mindfulness, Regular Immersion in N...            <=2
# 36                 Meditation/Mindfulness, Breath work            <=2
# 37            Breath work, Regular Immersion in Nature            3-5
# 38   Meditation/Mindfulness, Breath work, Yoga/Mart...            <=2
# 39                              Meditation/Mindfulness            <=2
# 40      Yoga/Martial Arts, Regular Immersion in Nature            <=2
# 41                                                 NaN            3-5
# 42                      Breath work, Yoga/Martial Arts            3-5
# 43                                                 NaN            3-5
# 44                                         Breath work            <=2
# 45   Meditation/Mindfulness, Breath work, Yoga/Mart...            3-5
# 46                                                 NaN            3-5
# 47                                                 NaN            3-5
# 48                                   Artistic Creation            3-5
# 49      Artistic Creation, Regular Immersion in Nature            3-5
# 50                                                 NaN            3-5
# 51                              Meditation/Mindfulness            3-5
# 52                                   Artistic Creation             6+
# 53                                   Artistic Creation            3-5
# 54                                                 NaN            3-5
# 55                                   Artistic Creation            3-5
# 56                              Meditation/Mindfulness             6+
# 57                              Meditation/Mindfulness            3-5
# 58                 Meditation/Mindfulness, Breath work            3-5
# 59   Meditation/Mindfulness, Yoga/Martial Arts, Reg...            3-5
# 60                                                 NaN             6+
# 61                                                 NaN            3-5
# 62                                                 NaN            3-5
# 63                                                 NaN             6+
# 64                                   Yoga/Martial Arts             6+
# 65   Meditation/Mindfulness, Regular Immersion in N...             6+
# 66                                   Artistic Creation             6+
# 67            Breath work, Regular Immersion in Nature             6+
# 68   Meditation/Mindfulness, Regular Immersion in N...            3-5
# 69                                                 NaN             6+
# 70                                                 NaN            3-5
# 71                              Meditation/Mindfulness            3-5
# 72   Meditation/Mindfulness, Yoga/Martial Arts, Art...            3-5
# 73   Meditation/Mindfulness, Regular Immersion in N...             6+
# 74                                                 NaN            3-5
# 75                                   Artistic Creation            3-5
# 76                                                 NaN            3-5
# 77                                                 NaN            3-5
# 78           Meditation/Mindfulness, Artistic Creation            3-5
# 79            Breath work, Regular Immersion in Nature            <=2
# 80   Meditation/Mindfulness, Yoga/Martial Arts, Reg...            3-5
# 81                                   Artistic Creation            3-5
# 82      Artistic Creation, Regular Immersion in Nature            <=2
# 83                         Regular Immersion in Nature            3-5
# 84                                                 NaN            3-5
# 85                 Meditation/Mindfulness, Breath work            <=2
# 86                                                 NaN            3-5
# 87                              Meditation/Mindfulness            3-5
# 88                                   Artistic Creation            3-5
# 89   Meditation/Mindfulness, Artistic Creation, Reg...            3-5
# 90                                                 NaN            3-5
# 91                                   Artistic Creation            <=2
# 92                                                 NaN            3-5
# 93                                   Artistic Creation            <=2
# 94                                                 NaN            <=2
# 95                   Regular Immersion in Nature, None             6+
# 96                                                 NaN            <=2
# 97                         Regular Immersion in Nature            3-5
# 98                                                 NaN            3-5
# 99                                                 NaN            3-5
# 100                        Regular Immersion in Nature            <=2
#
#     gender_assigned gender_identity                edu_level  ...  \
# 0            Female          Female            Undergraduate  ...
# 1              Male            Male  High school Diploma/GED  ...
# 2            Female          Female  High school Diploma/GED  ...
# 3            Female          Female  High school Diploma/GED  ...
# 4            Female          Female  High school Diploma/GED  ...
# 5            Female          Female            Undergraduate  ...
# 6              Male            Male  High school Diploma/GED  ...
# 7            Female          Female  High school Diploma/GED  ...
# 8            Female          Female                 Graduate  ...
# 9            Female          Female  High school Diploma/GED  ...
# 10             Male            Male        Associates Degree  ...
# 11           Female          Female  High school Diploma/GED  ...
# 12             Male           Other  High school Diploma/GED  ...
# 13             Male            Male            Undergraduate  ...
# 14           Female          Female        Associates Degree  ...
# 15              NaN          Female  High school Diploma/GED  ...
# 16             Male            Male  High school Diploma/GED  ...
# 17           Female          Female            Undergraduate  ...
# 18           Female          Female            Undergraduate  ...
# 19           Female          Female                 Graduate  ...
# 20             Male            Male            Undergraduate  ...
# 21           Female          Female                 Graduate  ...
# 22             Male            Male            Undergraduate  ...
# 23           Female          Female  High school Diploma/GED  ...
# 24           Female          Female            Undergraduate  ...
# 25           Female          Female                 Graduate  ...
# 26           Female          Female                 Graduate  ...
# 27           Female          Female            Undergraduate  ...
# 28           Female          Female            Undergraduate  ...
# 29             Male            Male            Undergraduate  ...
# 30           Female          Female                 Graduate  ...
# 31           Female          Female                 Graduate  ...
# 32             Male            Male            Undergraduate  ...
# 33             Male            Male                 Graduate  ...
# 34           Female          Female            Undergraduate  ...
# 35             Male            Male                 Graduate  ...
# 36             Male            Male            Undergraduate  ...
# 37             Male            Male            Undergraduate  ...
# 38             Male            Male                 Graduate  ...
# 39             Male            Male            Undergraduate  ...
# 40             Male            Male                 Graduate  ...
# 41             Male            Male  High school Diploma/GED  ...
# 42           Female          Female  High school Diploma/GED  ...
# 43           Female          Female        Associates Degree  ...
# 44             Male            Male            Undergraduate  ...
# 45             Male            Male        Associates Degree  ...
# 46           Female          Female        Associates Degree  ...
# 47             Male            Male  High school Diploma/GED  ...
# 48             Male            Male            Undergraduate  ...
# 49             Male            Male        Associates Degree  ...
# 50           Female          Female            Undergraduate  ...
# 51             Male            Male  High school Diploma/GED  ...
# 52           Female          Female        Associates Degree  ...
# 53           Female          Female        Associates Degree  ...
# 54           Female          Female  High school Diploma/GED  ...
# 55           Female          Female  High school Diploma/GED  ...
# 56           Female          Female  High school Diploma/GED  ...
# 57           Female          Female  High school Diploma/GED  ...
# 58           Female          Female  High school Diploma/GED  ...
# 59           Female          Female            Undergraduate  ...
# 60           Female          Female            Undergraduate  ...
# 61             Male            Male  High school Diploma/GED  ...
# 62           Female          Female        Associates Degree  ...
# 63             Male            Male  High school Diploma/GED  ...
# 64             Male            Male  High school Diploma/GED  ...
# 65           Female          Female  High school Diploma/GED  ...
# 66           Female          Female        Associates Degree  ...
# 67           Female          Female  High school Diploma/GED  ...
# 68           Female          Female  High school Diploma/GED  ...
# 69           Female          Female            Undergraduate  ...
# 70           Female          Female            Undergraduate  ...
# 71           Female          Female  High school Diploma/GED  ...
# 72           Female          Female            Undergraduate  ...
# 73           Female          Female  High school Diploma/GED  ...
# 74             Male            Male            Undergraduate  ...
# 75           Female          Female  High school Diploma/GED  ...
# 76           Female          Female  High school Diploma/GED  ...
# 77           Female          Female                 Graduate  ...
# 78           Female          Female  High school Diploma/GED  ...
# 79           Female           Other  High school Diploma/GED  ...
# 80           Female          Female  High school Diploma/GED  ...
# 81           Female          Female  High school Diploma/GED  ...
# 82           Female           Other  High school Diploma/GED  ...
# 83           Female          Female  High school Diploma/GED  ...
# 84           Female          Female            Undergraduate  ...
# 85             Male            Male                 Graduate  ...
# 86           Female          Female  High school Diploma/GED  ...
# 87             Male            Male            Undergraduate  ...
# 88           Female          Female                 Graduate  ...
# 89           Female          Female            Undergraduate  ...
# 90             Male            Male            Undergraduate  ...
# 91           Female          Female                 Graduate  ...
# 92           Female          Female            Undergraduate  ...
# 93           Female          Female            Undergraduate  ...
# 94           Female          Female            Undergraduate  ...
# 95           Female          Female  High school Diploma/GED  ...
# 96           Female           Other        Associates Degree  ...
# 97             Male            Male                 Graduate  ...
# 98           Female          Female            Undergraduate  ...
# 99           Female          Female                 Graduate  ...
# 100          Female          Female            Undergraduate  ...
#
#     trigger_spiritual_8 trigger_phys_10 trigger_phys_11  trigger_phys_12  \
# 0                   3.0             3.0             3.0              3.0
# 1                   1.0             2.0             2.0              4.0
# 2                   3.0             3.0             4.0              3.0
# 3                   2.0             2.0             2.0              2.0
# 4                   3.0             3.0             2.0              3.0
# 5                   5.0             4.0             5.0              5.0
# 6                   3.0             2.0             2.0              1.0
# 7                   1.0             4.0             3.0              3.0
# 8                   4.0             4.0             3.0              4.0
# 9                   3.0             2.0             2.0              3.0
# 10                  1.0             1.0             1.0              1.0
# 11                  1.0             3.0             3.0              4.0
# 12                  2.0             2.0             2.0              1.0
# 13                  2.0             3.0             2.0              2.0
# 14                  5.0             2.0             4.0              2.0
# 15                  3.0             4.0             5.0              5.0
# 16                  1.0             4.0             3.0              5.0
# 17                  4.0             2.0             2.0              2.0
# 18                  5.0             5.0             5.0              5.0
# 19                  5.0             1.0             1.0              4.0
# 20                  2.0             1.0             1.0              1.0
# 21                  1.0             3.0             3.0              4.0
# 22                  3.0             3.0             4.0              3.0
# 23                  1.0             3.0             3.0              3.0
# 24                  1.0             3.0             3.0              2.0
# 25                  2.0             3.0             3.0              2.0
# 26                  1.0             1.0             1.0              1.0
# 27                  3.0             1.0             1.0              3.0
# 28                  3.0             1.0             1.0              1.0
# 29                  3.0             2.0             1.0              4.0
# 30                  4.0             4.0             4.0              4.0
# 31                  1.0             4.0             2.0              5.0
# 32                  3.0             5.0             4.0              4.0
# 33                  2.0             5.0             2.0              4.0
# 34                  5.0             3.0             2.0              4.0
# 35                  1.0             4.0             3.0              4.0
# 36                  4.0             5.0             4.0              3.0
# 37                  4.0             4.0             2.0              4.0
# 38                  4.0             4.0             2.0              3.0
# 39                  2.0             5.0             4.0              5.0
# 40                  2.0             4.0             4.0              4.0
# 41                  2.0             4.0             4.0              3.0
# 42                  3.0             3.0             3.0              3.0
# 43                  2.0             3.0             3.0              4.0
# 44                  3.0             3.0             3.0              3.0
# 45                  3.0             3.0             4.0              5.0
# 46                  3.0             3.0             2.0              4.0
# 47                  3.0             3.0             3.0              3.0
# 48                  4.0             1.0             1.0              1.0
# 49                  3.0             2.0             3.0              3.0
# 50                  3.0             4.0             4.0              4.0
# 51                  3.0             4.0             4.0              3.0
# 52                  3.0             3.0             2.0              4.0
# 53                  1.0             1.0             1.0              3.0
# 54                  5.0             3.0             1.0              1.0
# 55                  3.0             2.0             2.0              3.0
# 56                  2.0             3.0             3.0              3.0
# 57                  4.0             2.0             3.0              5.0
# 58                  1.0             3.0             2.0              4.0
# 59                  2.0             2.0             2.0              1.0
# 60                  4.0             3.0             3.0              4.0
# 61                  1.0             2.0             1.0              4.0
# 62                  3.0             3.0             3.0              NaN
# 63                  NaN             NaN             NaN              NaN
# 64                  2.0             2.0             2.0              2.0
# 30   Out-of-State Private              Yes
# 31         Other/Multiple              Yes
# 32   Out-of-State Private               No
# 33   Out-of-State Private               No
# 34    Out-of-State Public         Not Sure
# 35    Out-of-State Public         Not Sure
# 36         Other/Multiple               No
# 37         Other/Multiple               No
# 38   Out-of-State Private         Not Sure
# 39    Out-of-State Public               No
# 40   Out-of-State Private         Not Sure
# 41         Other/Multiple               No
# 42        WA State Public               No
# 43      Community College               No
# 44       WA State Private              Yes
# 45         Other/Multiple         Not Sure
# 46        WA State Public         Not Sure
# 47        WA State Public              Yes
# 48       WA State Private              Yes
# 49        WA State Public         Not Sure
# 50        WA State Public         Not Sure
# 51        WA State Public         Not Sure
# 52        WA State Public              Yes
# 53        WA State Public         Not Sure
# 54        WA State Public         Not Sure
# 55        WA State Public         Not Sure
# 56        WA State Public               No
# 57        WA State Public               No
# 58        WA State Public               No
# 59        WA State Public              Yes
# 60        WA State Public              Yes
# 61        WA State Public              Yes
# 62        WA State Public         Not Sure
# 63      Community College               No
# 64        WA State Public               No
# 65        WA State Public         Not Sure
# 66        WA State Public         Not Sure
# 67        WA State Public         Not Sure
# 68        WA State Public         Not Sure
# 69        WA State Public         Not Sure
# 70        WA State Public              NaN
# 71        WA State Public              Yes
# 72        WA State Public         Not Sure
# 73        WA State Public         Not Sure
# 74        WA State Public         Not Sure
# 75        WA State Public         Not Sure
# 76        WA State Public         Not Sure
# 77        WA State Public         Not Sure
# 78        WA State Public         Not Sure
# 79        WA State Public               No
# 80        WA State Public               No
# 81    Out-of-State Public              Yes
# 82        WA State Public              Yes
# 83         Other/Multiple               No
# 84        WA State Public              Yes
# 85        WA State Public              Yes
# 86         Other/Multiple         Not Sure
# 87        WA State Public               No
# 88        WA State Public         Not Sure
# 89        WA State Public         Not Sure
# 90         Other/Multiple              Yes
# 91        WA State Public         Not Sure
# 92        WA State Public               No
# 93        WA State Public               No
# 94        WA State Public               No
# 95         Other/Multiple         Not Sure
# 96      Community College         Not Sure
# 97        WA State Public               No
# 98        WA State Public               No
# 99         Other/Multiple              Yes
# 100       WA State Public               No
#
# [101 rows x 71 columns]>

# %%
# Select your phenotype features
phenotype_features = [
    'age_range', 'env_growth', 'worldview', 'activity_primary', 
    'gender_assigned', 'edu_level', 'income_bracket', 'socioec_status', 
    'awe_scale_1',
'awe_scale_2',
'awe_scale_3',
'awe_scale_4',
'awe_scale_5',
'awe_scale_6',
'awe_scale_7',
'awe_scale_8',
'awe_scale_9',
'awe_scale_10',
'awe_scale_11',
'awe_scale_12'
]

# One-hot encode the text categories
X_encoded = pd.get_dummies(cleaned_data[phenotype_features], drop_first=True)

# %%
# 2. Impute (looks at 5 nearest neighbors by default)
imputer = KNNImputer(n_neighbors=5)
X_imputed = imputer.fit_transform(X_encoded)

# 3. Scale
X_scaled = scaler.fit_transform(X_imputed)

# There a NaN values in some of the columns (example regular_practices has 34 NaNs).
# However, dropping all rows with NaN dimishes the value in an alredy small dataset.
# Using KNN Imputer:
# looks at other "similar" respondents. If a respondent looks like Cluster A in every 
#     other category but is missing their awe_scale_5 score, it will fill that gap based 
#     on the scores of people similar to them.

# %%
# Scale the data (Essential for K-Means to treat 1-5 scales and 0/1 dummies fairly)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_imputed)

# 3. Build the Cluster Model
# We'll stick with 3 clusters to look for distinct "Phenotypes"
kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
cleaned_data['cluster'] = kmeans.fit_predict(X_scaled)

# 4. Dimensionality Reduction for Visualization
pca = PCA(n_components=2)
pca_data = pca.fit_transform(X_scaled)
cleaned_data['pca_1'] = pca_data[:, 0]
cleaned_data['pca_2'] = pca_data[:, 1]

# 5. ANALYSIS: Identify the "Awe Phenotypes"
# We look at the average scores for each cluster to define them
phenotype_profiles = cleaned_data.groupby('cluster')[phenotype_features].agg(lambda x: x.mode()[0])
print("--- Phenotype Profiles (Dominant Traits) ---")
print(phenotype_profiles)
# Out:
# --- Phenotype Profiles (Dominant Traits) ---
#         age_range env_growth                    worldview activity_primary  \
# cluster
# 0           25-30   Suburban  Spiritual but not Religious             Work
# 1           19-21   Suburban           Religious/Theistic         Studying
# 2           22-24   Suburban           Atheist/Naturalist             Work
#
#         gender_assigned                edu_level income_bracket  \
# cluster
# 0                Female            Undergraduate          0-50K
# 1                Female  High school Diploma/GED          0-50K
# 2                Female            Undergraduate          0-50K
#
#              socioec_status  awe_scale_1  awe_scale_2  awe_scale_3  \
# cluster
# 0          Low middle class            4            4            5
# 1        Upper middle class            4            4            4
# 2          Low middle class            4            4            4
#
#          awe_scale_4  awe_scale_5  awe_scale_6  awe_scale_7  awe_scale_8  \
# cluster
# 0                  4            3            3            5          4.0
# 1                  3            4            3            4          3.0
# 2                  4            4            1            2          1.0
#
#          awe_scale_9  awe_scale_10  awe_scale_11  awe_scale_12
# cluster
# 0                5.0             3             3           2.0
# 1                2.0             3             3           2.0
# 2                2.0             2             2           2.0

# %%
# 6. TARGET LINK: How does each phenotype relate to the SPARK trait?
# Assuming 'chills_ability' is coded as 0/1 or Yes/No
spark_link = cleaned_data.groupby('cluster')['chills_ability'].value_counts(normalize=True).unstack() * 100
print("\n--- SPARK Trait (chills_ability) Distribution per Cluster (%) ---")
print(spark_link)

# 7. Visualize the Phenotype Map
pheno_colors = ["#00C2AE", "#74E8BF", "#C7F0B9"]

plt.figure(figsize=(10, 6))
sns.scatterplot(data=cleaned_data, x='pca_1', y='pca_2', hue='cluster', palette=pheno_colors, edgecolor='black', alpha=0.8, s=100)

# Titles - bolded, fontsize 14
plt.title('Awe Phenotype Map (PCA Projection)', fontsize=14, fontweight='bold', pad=15)

# Axis Labels - fontsize 12
plt.xlabel('Principal Component 1', fontsize=12)
plt.ylabel('Principal Component 2', fontsize=12)

# Grid Lines - color grey, weight 0.1-0.4
# Note: linewidth (lw) set to 0.4 for a subtle but visible look
plt.grid(True, color='grey', linestyle='-', linewidth=0.4, alpha=0.5)

# Move legend to the side so it doesn't block the grid
plt.legend(title='Phenotype Cluster', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()
# Out:
# --- SPARK Trait (chills_ability) Distribution per Cluster (%) ---
# chills_ability        0.0        1.0
# cluster
# 0               60.714286  39.285714
# 1               70.833333  29.166667
# 2               73.913043  26.086957

# %%
copy_df = cleaned_data.copy()
# print(copy_df.head)
# Pass the entire dataframe, but tell it which columns to encode
# This keeps all other columns exactly as they are.
encodedCopyDf = pd.get_dummies(copy_df, columns=phenotype_features, drop_first=True)

# Now df_encoded contains your original scale scores + the new dummy variables
# print(encodedCopyDf)

# %%
# 1. Convert the cluster column to string directly in cleaned_data
# This ensures Plotly treats them as discrete categories (colors) rather than a continuous scale
cleaned_data['cluster'] = cleaned_data['cluster'].astype(str)
cleaned_data['Participant_ID'] = cleaned_data.index + 1

# 2. Map your scores for the ternary axes
cleaned_data['Religious_Score'] = cleaned_data['trigger_spiritual_1'] + cleaned_data['trigger_spiritual_2']
cleaned_data['Naturalist_Score'] = cleaned_data['trigger_spiritual_4']
cleaned_data['Spiritual_Score'] = cleaned_data['trigger_spiritual_3']

# %%
# 3. Build the plot using cleaned_data
fig = px.scatter_ternary(
    cleaned_data, 
    a="Religious_Score", 
    b="Naturalist_Score", 
    c="Spiritual_Score",
    color="cluster",           
    symbol="chills_ability",   
    size_max=15,
    # Plotly titles use HTML tags for bolding
    title="<b>Worldview Triggers vs. Chills Ability</b>",
    labels={
        "Religious_Score": "Theistic Triggers", 
        "Naturalist_Score": "Naturalist Triggers", 
        "Spiritual_Score": "Spiritual Triggers"
    },
    color_discrete_sequence=pheno_colors, # Applying your hex colors
    hover_data=['Participant_ID', 'worldview']
)

# Update layout for larger display and specific styling
fig.update_layout({
    'width': 1000,
    'height': 800,
    'title': {
        'font': {'size': 14}, # Requested title size
        'x': 0.5,             # Center the title
        'xanchor': 'center'
    },
    'ternary': {
        'sum': None,
        'aaxis': {
            'title': 'Religious', 
            'titlefont': {'size': 12}, # Requested axis label size
            'gridcolor': '#E3E3E3',       # Grid color
            'gridwidth': 0.4           # Grid weight
        },
        'baxis': {
            'title': 'Naturalist', 
            'titlefont': {'size': 12}, 
            'gridcolor': '#E3E3E3', 
            'gridwidth': 0.4
        },
        'caxis': {
            'title': 'Spiritual', 
            'titlefont': {'size': 12}, 
            'gridcolor': '#E3E3E3', 
            'gridwidth': 0.4
        },
        'bgcolor': '#005248' # Keeps the background clean for the grey grid
    },
    'legend': {'font': {'size': 12}},
    'font': {'family': "Arial"} # Clean font for all text
})

fig.show()

# %%
# # Loop through each cluster and each chills_ability status
# for cluster_id in cleaned_data['cluster'].unique():
#     for ability in cleaned_data['chills_ability'].unique():
        
#         # 3. Create the subset
#         subset = cleaned_data[
#             (cleaned_data['cluster'] == cluster_id) & 
#             (cleaned_data['chills_ability'] == ability)
#         ]
        
#         # 4. Generate a clean filename
#         # Replaces spaces or special characters to avoid file errors
#         safe_ability = str(ability).replace(" ", "_").lower()
#         filename = f"cluster_{cluster_id}_chills_{safe_ability}.csv"
        
#         # 5. Save the CSV
#         if not subset.empty:
#             subset.to_csv(filename, index=False)
#             print(f"Saved: {filename} ({len(subset)} participants)")

# Gets row data for each identified cluster and exports as csv
